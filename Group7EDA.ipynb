# %% [markdown]
# <a href="https://colab.research.google.com/github/Keltings/Soccer/blob/main/Group7EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans

# %matplotlib inline

# %%
soccer_cluster = pd.read_csv('https://raw.githubusercontent.com/Keltings/Soccer/main/soccer_cluster.csv')
soccer_KNN = pd.read_csv('https://raw.githubusercontent.com/Keltings/Soccer/main/soccer_KNN.csv')

match = soccer_cluster.copy()

# %%
# filter home matches
home_matches = match[match['Venue'] == 'Home']
# filter away matches
away_matches = match[match['Venue'] == 'Away']

away_matches
# Out:
#       Time  MatchWeek  Day Venue Result  GoalsFor  GoalsAgainst  \
# 1     15.0          2  Sat  Away    Win         2             1
# 3     17.0          4  Sat  Away    Win         3             0
# 5     16.0          6  Sun  Away    Win         2             1
# 6     12.0          7  Sat  Away    Win         1             0
# 8     16.0          9  Sun  Away   Draw         1             1
# ...    ...        ...  ...   ...    ...       ...           ...
# 5083  15.8         30  Sat  Away   Loss         1             2
# 5085  15.8         32  Sat  Away   Loss         1             2
# 5087  15.8         34  Sat  Away   Draw         0             0
# 5089  15.8         36  Sat  Away   Draw         4             4
# 5091  15.8         38  Sun  Away   Loss         2             3
#
#             Opponent  ExpectedGoals  ExpectedGoalsAgainst  ...  \
# 1        Southampton            1.3                   1.9  ...
# 3            Burnley            1.0                   0.9  ...
# ...

# %% [markdown]
# ### What is the correlation between a team's possession of the ball and their number of wins?
